# %%
import matplotlib.pyplot as plt
import math

pos1=[5,5]

pos2=pos1
pos2[0]=pos1[0]*(1+math.sin(math.pi/6))
pos2[1]=pos1[1]*(1+math.sin(math.pi/6))

circle1=plt.Circle(pos1,0.3,color='r')
circle2=plt.Circle(pos2,0.3,color='blue')
fig, ax = plt.subplots()
fig.set_size_inches(10,10)
ax.add_patch(circle1)
ax.add_patch(circle2)
ax.set_xlim(10)
ax.set_ylim(10)
plt.show()

# %%
import seaborn as sns

def getGridPoints(center_point,grid_size,step_size):
    start=(center_point[0] -(grid_size[0]*step_size)/1,center_point[1] -(grid_size[1]*step_size)/1)
    step=step_size
    points=[]
    radius=step*(math.sin(math.pi/6))
    numsx=[start[0]]
    numsy=[start[1]]
    sizes=[radius]

    #fig,ax=plt.subplots(1,1)
    #fig.set_size_inches(15,15)
    for i in range(0,grid_size[0]):
        for j in range(0,grid_size[1]):

            x=((j%2==0)*(radius))+start[0]+(i*0.94)*(step*math.cos(math.pi/6))
            y=start[1]+((j*0.94)* step * math.cos(math.pi/6))
            points.append((x,y))
            #numsx.append(x)
            #numsy.append(y)
            #sizes.append(radius)
            #ax.add_patch(plt.Circle((x,y),radius,color='red',alpha=0.2))

    #ax.scatter(x=numsx,y=numsy,sizes=sizes)
    return points

    
getGridPoints((10,10),(20,20),1.2)
# Out:
# [(-13.4, -14.0),
#  (-14.0, -13.023123344531154),
#  (-13.4, -12.046246689062306),
#  (-14.0, -11.06937003359346),
#  (-13.4, -10.092493378124614),
#  (-14.0, -9.115616722655766),
#  (-13.4, -8.13874006718692),
#  (-14.0, -7.161863411718072),
#  (-13.4, -6.184986756249226),
#  (-14.0, -5.208110100780379),
#  (-13.4, -4.231233445311533),
#  (-14.0, -3.254356789842685),
#  (-13.4, -2.277480134373839),
#  (-14.0, -1.3006034789049927),
#  (-13.4, -0.3237268234361448),
#  (-14.0, 0.6531498320327014),
#  (-13.4, 1.6300264875015475),
#  (-14.0, 2.6069031429703955),
#  (-13.4, 3.5837797984392417),
#  (-14.0, 4.560656453908088),
#  (-12.423123344531154, -14.0),
#  (-13.023123344531154, -13.023123344531154),
#  (-12.423123344531154, -12.046246689062306),
#  (-13.023123344531154, -11.06937003359346),
#  (-12.423123344531154, -10.092493378124614),
#  (-13.023123344531154, -9.115616722655766),
#  (-12.423123344531154, -8.13874006718692),
#  (-13.023123344531154, -7.161863411718072),
# ...
