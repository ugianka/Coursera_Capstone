# %% [markdown]
# # Capstone Notebook

# %% [markdown]
# this notebook will be __mainly__ used for the capstone project.

# %%
import pandas as pd
import numpy as np

# %%
print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!

# %%
import requests

# %%
uri="https://api.foursquare.com/v2/venues/search?client_id=V5TQ0NXY4D1FWWPLNLJUKXRCC4K3ZKWQ4OFKZOZ10TMZS33O&client_secret=HEXKQC41N1YTKLU1ICVOAFMO04QXHK0LNONCAAH3QT2PI5TJ&ll=40.7,-74&query=sushi&v=20200101"

r=requests.get(uri)

# %%
CLIENT_ID=''
CLIENT_SECRET=''
ACCESS_TOKEN=''
latitude=40.7149555 
longitude=-74.0153365
VERSION=''
search_query = 'Italian'
radius = 500
LIMIT=''

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)
url
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-680164bc9bc6> in <module>
# ----> 1 url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)
#       2 url
#
# NameError: name 'CLIENT_ID' is not defined

# %%
r.text
# Out:
# '{"meta":{"code":200,"requestId":"600fed3e3cdc3e13946fb37e"},"response":{"venues":[{"id":"4a5e00d9f964a520e2bd1fe3","name":"Shinju Sushi","location":{"address":"164 Pearl Street","crossStreet":"btwn Pine & Wall St.","lat":40.70607040649608,"lng":-74.00743262495199,"labeledLatLngs":[{"label":"display","lat":40.70607040649608,"lng":-74.00743262495199}],"distance":921,"postalCode":"10005","cc":"US","city":"Manhattan","state":"NY","country":"United States","formattedAddress":["164 Pearl Street (btwn Pine & Wall St.)","Manhattan, NY 10005","United States"]},"categories":[{"id":"4bf58dd8d48988d111941735","name":"Japanese Restaurant","pluralName":"Japanese Restaurants","shortName":"Japanese","icon":{"prefix":"https:\\/\\/ss3.4sqi.net\\/img\\/categories_v2\\/food\\/japanese_","suffix":".png"},"primary":true}],"referralId":"v-1611656510","hasPerk":false},{"id":"4f415376e4b08cc37282ff20","name":"Whole Foods Sushi Bar","location":{"address":"Whole Foods Market","lat":40.72399989837209,"lng":-73
# ...

# %%
data=r.json()

# %%
df=pd.DataFrame(data['response']['venues'])

# %%
df
# Out:
#                           id                                     name  \
# 0   4a5e00d9f964a520e2bd1fe3                             Shinju Sushi
# 1   4f415376e4b08cc37282ff20                    Whole Foods Sushi Bar
# 2   5bca0ff80ff4f9002cd191b4                              Bento Sushi
# 3   5823559732824866cf704f5e                               Sabi Sushi
# 4   4b1ee4e1f964a520332124e3                              Kyoto Sushi
# 5   4bb38ae6715eef3bcc7b86bb                       Okami Fusion Sushi
# 6   4ae7a786f964a52019ad21e3                           New Koto Sushi
# 7   4e4e4c36bd4101d0d7a71fab                               Kuki Sushi
# 8   4c6c32b0e13db60c0265d5b1                                 JR Sushi
# 9   45ac12d6f964a5205d411fe3                        Blue Ribbon Sushi
# 10  4cc4ab91bde8f04d93e6ac4b                              Genji Sushi
# 11  4aad744bf964a520606020e3                              Sushi Azabu
# ...
